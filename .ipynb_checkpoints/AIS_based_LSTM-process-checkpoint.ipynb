# %%
# !pip install basemap
# !pip install basemap-data-hires
# !pip install geopandas
# !pip install openturns
# Out:
# Collecting basemap
#   Downloading basemap-1.3.7-cp310-cp310-manylinux1_x86_64.whl (860 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 860.6/860.6 kB 6.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting pyproj<3.6.0,>=1.9.3
#   Downloading pyproj-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 10.6 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting pyshp<2.4,>=1.2
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.25,>=1.22 in /home/mingi/anaconda3/lib/python3.10/site-packages (from basemap) (1.23.5)
# Collecting basemap-data<1.4,>=1.3.2
#   Downloading basemap_data-1.3.2-py2.py3-none-any.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 10.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: matplotlib<3.8,>=1.5 in /home/mingi/anaconda3/lib/python3.10/site-packages (from basemap) (3.7.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mingi/anaconda3/lib/python3.10/site-packages (from matplotlib<3.8,>=1.5->basemap) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mingi/anaconda3/lib/python3.10/site-packages (from matplotlib<3.8,>=1.5->basemap) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mingi/anaconda3/lib/python3.10/site-packages (from matplotlib<3.8,>=1.5->basemap) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/mingi/anaconda3/lib/python3.10/site-packages (from matplotlib<3.8,>=1.5->basemap) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/mingi/anaconda3/lib/python3.10/site-packages (from matplotlib<3.8,>=1.5->basemap) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mingi/anaconda3/lib/python3.10/site-packages (from matplotlib<3.8,>=1.5->basemap) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /home/mingi/anaconda3/lib/python3.10/site-packages (from matplotlib<3.8,>=1.5->basemap) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mingi/anaconda3/lib/python3.10/site-packages (from matplotlib<3.8,>=1.5->basemap) (1.0.5)
# Requirement already satisfied: certifi in /home/mingi/anaconda3/lib/python3.10/site-packages (from pyproj<3.6.0,>=1.9.3->basemap) (2023.5.7)
# Requirement already satisfied: six>=1.5 in /home/mingi/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<3.8,>=1.5->basemap) (1.16.0)
# Installing collected packages: pyshp, pyproj, basemap-data, basemap
# Successfully installed basemap-1.3.7 basemap-data-1.3.2 pyproj-3.5.0 pyshp-2.3.1
# Collecting basemap-data-hires
#   Downloading basemap_data_hires-1.3.2-py2.py3-none-any.whl (91.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 MB 9.2 MB/s eta 0:00:000m eta 0:00:010:00:01
# Installing collected packages: basemap-data-hires
# Successfully installed basemap-data-hires-1.3.2
# Collecting geopandas
#   Downloading geopandas-0.13.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 6.5 MB/s eta 0:00:006.4 MB/s eta 0:00:01
# Collecting fiona>=1.8.19
#   Downloading Fiona-1.9.4.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 9.9 MB/s eta 0:00:000m eta 0:00:010:01:01
# Requirement already satisfied: packaging in /home/mingi/anaconda3/lib/python3.10/site-packages (from geopandas) (22.0)
# Requirement already satisfied: pyproj>=3.0.1 in /home/mingi/anaconda3/lib/python3.10/site-packages (from geopandas) (3.5.0)
# Collecting shapely>=1.7.1
#   Downloading shapely-2.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 10.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: pandas>=1.1.0 in /home/mingi/anaconda3/lib/python3.10/site-packages (from geopandas) (1.5.3)
# Requirement already satisfied: certifi in /home/mingi/anaconda3/lib/python3.10/site-packages (from fiona>=1.8.19->geopandas) (2023.5.7)
# Requirement already satisfied: attrs>=19.2.0 in /home/mingi/anaconda3/lib/python3.10/site-packages (from fiona>=1.8.19->geopandas) (22.1.0)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: click~=8.0 in /home/mingi/anaconda3/lib/python3.10/site-packages (from fiona>=1.8.19->geopandas) (8.0.4)
# Requirement already satisfied: six in /home/mingi/anaconda3/lib/python3.10/site-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/mingi/anaconda3/lib/python3.10/site-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/mingi/anaconda3/lib/python3.10/site-packages (from pandas>=1.1.0->geopandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /home/mingi/anaconda3/lib/python3.10/site-packages (from pandas>=1.1.0->geopandas) (1.23.5)
# Installing collected packages: shapely, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.4.post1 geopandas-0.13.2 shapely-2.0.1
# Collecting openturns
#   Downloading openturns-1.21-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (59.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 MB 9.3 MB/s eta 0:00:000m eta 0:00:010:00:01
# Requirement already satisfied: psutil in /home/mingi/anaconda3/lib/python3.10/site-packages (from openturns) (5.9.0)
# Requirement already satisfied: dill in /home/mingi/anaconda3/lib/python3.10/site-packages (from openturns) (0.3.6)
# Installing collected packages: openturns
# Successfully installed openturns-1.21

# %%
# from google.colab import drive, files
# drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import math
import copy
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from matplotlib.ticker import (MultipleLocator,
                               FormatStrFormatter,
                               AutoMinorLocator)
from mpl_toolkits.basemap import Basemap
import geopandas as gpd
from scipy.spatial import ConvexHull
from timeit import default_timer as timer
from datetime import datetime
from datetime import timedelta
import openturns as ot
from openturns.viewer import View

# %%
file_name = "aisdk_20180101"
# date_df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/TOPOA/AIS data/denmark ais/dk_csv_20180101/aisdk_20180101.csv", encoding='unicode_escape')
date_df = pd.read_csv("./dk_csv_20180101/{}.csv".format(file_name), encoding='unicode_escape')

# %%
date_df
# Out:
#                  # Timestamp Type of mobile       MMSI   Latitude  Longitude  \
# 0        01/01/2018 00:00:00   Base Station    2194006  55.538917   5.033400
# 1        01/01/2018 00:00:00   Base Station    2194005  56.344267   4.272000
# 2        01/01/2018 00:00:00        Class A  219001061  55.716887  12.593578
# 3        01/01/2018 00:00:00        Class A  236407000  57.423072   8.690758
# 4        01/01/2018 00:00:00        Class A  265513250  56.157983  15.594550
# ...                      ...            ...        ...        ...        ...
# 9648797  01/01/2018 23:59:58        Class A  259278000  58.284182  10.591812
# 9648798  01/01/2018 23:59:58        Class A      11388  57.047778  10.050150
# 9648799  01/01/2018 23:59:58        Class A  219015425  55.467877  10.528980
# 9648800  01/01/2018 23:59:58        Class A  220118000  56.701880   8.218810
# 9648801  01/01/2018 23:59:58        Class A  266306000  57.598675  11.793760
#
#             Navigational status  ROT   SOG    COG  Heading  ...  \
# 0                 Unknown value  NaN   NaN    NaN      NaN  ...
# 1                 Unknown value  NaN   NaN    NaN      NaN  ...
# 2        Under way using engine  0.0   0.0   78.8     20.0  ...
# 3        Under way using engine -3.6  11.6   51.5     53.0  ...
# 4        Under way using engine  NaN   0.0   19.3      NaN  ...
# ...                         ...  ...   ...    ...      ...  ...
# 9648797  Under way using engine  NaN  10.6  167.6    176.0  ...
# 9648798  Under way using engine  NaN   0.0  179.0      NaN  ...
# 9648799  Under way using engine  0.0   0.0  310.7     36.0  ...
# 9648800  Under way using engine  0.0   0.0  287.2    235.0  ...
# 9648801      Engaged in fishing  0.0   0.0  339.2     20.0  ...
#
#                      Name  Ship type Cargo type Width Length  \
# 0                     NaN  Undefined        NaN   NaN    NaN
# 1                     NaN  Undefined        NaN   NaN    NaN
# 2                     NaN  Undefined        NaN   NaN    NaN
# 3                     NaN  Undefined        NaN   NaN    NaN
# 4                     NaN  Undefined        NaN   NaN    NaN
# ...                   ...        ...        ...   ...    ...
# 9648797      COLOR VIKING  Passenger        NaN  24.0  137.0
# 9648798  AALBORG EASTPORT  Undefined        NaN   NaN    NaN
# 9648799      SVITZER THOR        Tug        NaN  13.0   33.0
# 9648800      L620 AUSTRIA    Fishing        NaN   4.0   16.0
# 9648801            GANTHI    Fishing        NaN   6.0   21.0
#
#          Type of position fixing device  Draught    Destination  \
# 0                              Surveyed      NaN            NaN
# 1                              Surveyed      NaN            NaN
# 2                             Undefined      NaN            NaN
# 3                             Undefined      NaN            NaN
# 4                             Undefined      NaN            NaN
# ...                                 ...      ...            ...
# 9648797                             GPS      5.6  FREDERIKSHAVN
# 9648798                             GPS     25.5            NaN
# 9648799                             GPS      5.6          LINDO
# 9648800                             GPS      3.3       THYBORON
# 9648801                        Internal      NaN            NaN
#
#                          ETA Data source type
# 0                        NaN              AIS
# 1                        NaN              AIS
# 2                        NaN              AIS
# 3                        NaN              AIS
# 4                        NaN              AIS
# ...                      ...              ...
# 9648797  02/01/2018 04:00:00              AIS
# 9648798                  NaN              AIS
# 9648799  29/12/2018 12:00:00              AIS
# 9648800  22/10/2018 17:00:00              AIS
# 9648801                  NaN              AIS
#
# [9648802 rows x 22 columns]

# %%
def get_cartesian(lat=None,lon=None):
    # https://stackoverflow.com/a/55256861
    lat, lon = np.deg2rad(lat), np.deg2rad(lon)
    R = 6371 # radius of the earth (km)
    x = R * np.cos(lat) * np.cos(lon)
    y = R * np.cos(lat) * np.sin(lon)
    # z = R *np.sin(lat)
    return x,y

# %% [markdown]
# ## Data pre-procssing1 - GPS conversion

# %% [markdown]
# ### parameters

# %%
# Boundaries
left_x = 2000
right_x = 4000
upper_y = 700
lower_y = 300
spd_constraint = 0.2
encounter_dist = 2 # km
sampling_time = 15

# %%
gps_processed_df = date_df.copy()
gps_processed_df['pos_x'], gps_processed_df['pos_y'] = get_cartesian(date_df['Latitude'], date_df['Longitude'])

# %%
gps_processed_df.columns = gps_processed_df.columns.str.replace('# ', '')

# %%
gps_processed_df.head()
# Out:
#              Timestamp Type of mobile       MMSI   Latitude  Longitude  \
# 0  01/01/2018 00:00:00   Base Station    2194006  55.538917   5.033400
# 1  01/01/2018 00:00:00   Base Station    2194005  56.344267   4.272000
# 2  01/01/2018 00:00:00        Class A  219001061  55.716887  12.593578
# 3  01/01/2018 00:00:00        Class A  236407000  57.423072   8.690758
# 4  01/01/2018 00:00:00        Class A  265513250  56.157983  15.594550
#
#       Navigational status  ROT   SOG   COG  Heading  ... Cargo type Width  \
# 0           Unknown value  NaN   NaN   NaN      NaN  ...        NaN   NaN
# 1           Unknown value  NaN   NaN   NaN      NaN  ...        NaN   NaN
# 2  Under way using engine  0.0   0.0  78.8     20.0  ...        NaN   NaN
# 3  Under way using engine -3.6  11.6  51.5     53.0  ...        NaN   NaN
# 4  Under way using engine  NaN   0.0  19.3      NaN  ...        NaN   NaN
#
#   Length Type of position fixing device Draught  Destination  ETA  \
# 0    NaN                       Surveyed     NaN          NaN  NaN
# 1    NaN                       Surveyed     NaN          NaN  NaN
# 2    NaN                      Undefined     NaN          NaN  NaN
# 3    NaN                      Undefined     NaN          NaN  NaN
# 4    NaN                      Undefined     NaN          NaN  NaN
#
#   Data source type        pos_x       pos_y
# 0              AIS  3591.105094  316.290515
# 1              AIS  3521.007867  263.015558
# 2              AIS  3502.333952  782.452227
# 3              AIS  3390.960781  518.330148
# 4              AIS  3417.430862  953.813442
#
# [5 rows x 24 columns]

# %%
# crop the region and non-valid value
gps_processed_df = gps_processed_df.loc[(right_x >= gps_processed_df['pos_x']) & (gps_processed_df['pos_x'] >= left_x) & (upper_y >= gps_processed_df['pos_y']) \
                                        & (gps_processed_df['pos_y'] >= lower_y)].dropna(subset=['Timestamp','MMSI', 'Heading', 'SOG', 'COG'])

# %%
gps_processed_df['Timestamp'] =  pd.to_datetime(gps_processed_df['Timestamp'])
gps_processed_df['Timestamp'] =  gps_processed_df['Timestamp'].dt.strftime('%d/%m/%y %H:%M:%S')
# gps_processed_df['Timestamp']  = pd.to_datetime(gps_processed_df['Timestamp'], format='%d/%m/%y %H:%M:%S')

# %% [markdown]
# * trajectory linear interpolation
# * one ship --> other ships perspective

# %%
# gps_processed_df.head()['Navigational status'] != 'Under way using engine'
# gps_processed_df.head()

# %%
i =0
j= 0
found = False
df_entire_pass = pd.DataFrame()

for ego_id, df_by_ego_ID in gps_processed_df.groupby('MMSI'):
    # -------------------------------------------------------------------------------
    # ego vehicle
    # -------------------------------------------------------------------------------
    # edge case where it is not using engine
    if (df_by_ego_ID['Navigational status'] != 'Under way using engine').any():
        continue

    # 1) timestamp reindex for interpolate
    df_by_ego_ID['Timestamp'] =  pd.to_datetime(df_by_ego_ID['Timestamp'], format='%d/%m/%y %H:%M:%S')
    df_by_ego_ID = df_by_ego_ID.set_index('Timestamp')

    # 2) filling the gap
    # print(df_by_ego_ID)
    # df_by_ego_ID = df_by_ego_ID.drop_duplicates(subset=['Timestamp'])
    df_ego_interpol = df_by_ego_ID.resample("{}s".format(str(sampling_time))).mean(numeric_only=True) # mean or padding any other method?
    df_ego_interpol = df_ego_interpol.interpolate() # TODO linear or something?

    # print(df_ego_interpol)


    # -------------------------------------------------------------------------------
    # other vehicle
    # -------------------------------------------------------------------------------
    # TODO
    # 1) make a function

    for obj_id, df_by_obj_ID in gps_processed_df.groupby('MMSI'):
        # edge case: not ego vehicle
        if obj_id == ego_id:
            continue

        # 1) timestamp reindex for interpolate
        df_by_obj_ID['Timestamp'] =  pd.to_datetime(df_by_obj_ID['Timestamp'], format='%d/%m/%y %H:%M:%S')
        df_by_obj_ID = df_by_obj_ID.set_index('Timestamp')

        # 2) filling the gap
        df_obj_interpol = df_by_obj_ID.resample("{}s".format(str(sampling_time))).mean(numeric_only=True) # mean or padding any other method?
        df_obj_interpol = df_obj_interpol.interpolate() # TODO linear or something?

        # 3) find intersection
        # https://sparkbyexamples.com/pandas/find-intersection-between-two-series-in-pandas/?expand_article=1
        # time_intersect = set(df_ego_interpol.index) & set(df_obj_interpol.index)
        time_intersect = df_ego_interpol.index.intersection(df_obj_interpol.index)

        # 4) find closest distance meeting
        if len(time_intersect):
            df_rel_obj = pd.DataFrame()
            # dx_col = df_ego_interpol.loc[time_intersect]['pos_x'] - df_obj_interpol.loc[time_intersect]['pos_x']
            # dy_col = df_ego_interpol.loc[time_intersect]['pos_y'] - df_obj_interpol.loc[time_intersect]['pos_y']
            # dist_col = np.sqrt(dx_col**2 + dy_col**2)
            # atan_col = np.arctan2(dy_col, dx_col) # atan wrt my vehicle

            df_rel_obj['x'] = df_ego_interpol.loc[time_intersect]['pos_x'] - df_obj_interpol.loc[time_intersect]['pos_x']
            df_rel_obj['y'] = df_ego_interpol.loc[time_intersect]['pos_y'] - df_obj_interpol.loc[time_intersect]['pos_y']
            df_rel_obj['v_x'] = df_rel_obj['x'].diff() / 15.0 # TODO time sampling
            df_rel_obj['v_y'] = df_rel_obj['y'].diff() / 15.0

            df_rel_obj['rel_dist'] = np.sqrt(df_rel_obj['x']**2 + df_rel_obj['y']**2)
            df_rel_obj['rel_bearing'] = np.arctan2(df_rel_obj['y'], df_rel_obj['x']) # atan wrt my vehicle
            df_rel_obj['rel_bearing_diff'] = df_rel_obj['rel_bearing'].diff()
            df_rel_obj['Heading'] = df_obj_interpol['Heading']

            # within distance threshold
            encounter_cond = (df_rel_obj['rel_dist'] <= encounter_dist).any()
            if encounter_cond: # valid encounter
                

                """ encounter detail condition crop """
                df_rel_obj_crop = df_rel_obj.loc[(df_rel_obj['rel_dist'] <= 5)] # TODO TCPA-based, as this can address each vessel character
                # print("cropped", df_rel_obj_crop)
                end_idx = 0

                for k in range(len(df_rel_obj_crop)):
                    rel_dist = df_rel_obj_crop['rel_dist'].iloc[k]
                    rel_bearing = df_rel_obj_crop['rel_bearing'].iloc[k]

                    """ clearing condition """
                    if rel_dist >= 1 and abs(rel_bearing) >= math.radians(90):
                        # print("here enter")
                        end_idx = k
                        break
                # print("k value {}".format(end_idx))

                # TODO by function

                if end_idx != 0:

                    # 1) pos_x extraction to extract coming from front
                    df_rel_obj_crop = df_rel_obj_crop.iloc[:end_idx]

                    init_pos_x = df_rel_obj_crop['x'].iloc[0]
                    last_pos_x = df_rel_obj_crop['x'].iloc[-1]

                    if init_pos_x <= 0: # TODO backpassing (overtaking)
                        # df.loc[(df.obj_ID == obj_id), 'valid'] = False
                        # df_rel_obj_crop['valid'] = False
                        continue

                    else:
                        if last_pos_x <= 0:
                            # df.loc[(df.obj_ID == obj_id), 'valid'] = True
                            df_rel_obj_crop['valid'] = True
                            df_rel_obj_crop['obj_index'] = j
                            found = True

                            
                        else:
                            # df.loc[(df.obj_ID == obj_id), 'valid'] = False
                            # df_rel_obj_crop['valid'] = False
                            continue
                            
                    print("MMSI {} found valid ....... ".format(obj_id))

                    # 2) angle difference, r, and winding number
                    winding_number = df_rel_obj_crop['rel_bearing_diff'].sum()

                    if winding_number > 0:
                        # print("passing on my L side")
                        df_rel_obj_crop['label'] = 'L' # entire cell mapping

                    elif winding_number < 0:
                        # print("passing on my R side")
                        df_rel_obj_crop['label'] = 'R' # entire cell mapping

                    
                    # print("obj_index {}".format(df_rel_obj_crop))
                    
                    df_rel_obj_crop.to_pickle("./dk_csv_20180101/{}_{}.pkl".format(file_name, j))
                    print("{} th object saved ....... {}_{}.pkl".format(j, file_name, j))

                    # merge current object with entire dataframe
                    df_entire_pass = pd.concat([df_entire_pass, df_rel_obj_crop])
                    
                    j += 1


print("final {}".format(j))
# Out:
# MMSI 244850087 found valid .......
# 0 th object saved ....... aisdk_20180101_0.pkl
# MMSI 357562000 found valid .......
# 1 th object saved ....... aisdk_20180101_1.pkl
# MMSI 244621000 found valid .......
# 2 th object saved ....... aisdk_20180101_2.pkl
# MMSI 245655000 found valid .......
# 3 th object saved ....... aisdk_20180101_3.pkl
# MMSI 211135000 found valid .......
# 4 th object saved ....... aisdk_20180101_4.pkl
# MMSI 218767000 found valid .......
# 5 th object saved ....... aisdk_20180101_5.pkl
# MMSI 211315100 found valid .......
# 6 th object saved ....... aisdk_20180101_6.pkl
# MMSI 219021321 found valid .......
# 7 th object saved ....... aisdk_20180101_7.pkl
# MMSI 236446000 found valid .......
# 8 th object saved ....... aisdk_20180101_8.pkl
# MMSI 304080000 found valid .......
# 9 th object saved ....... aisdk_20180101_9.pkl
# MMSI 211187510 found valid .......
# 10 th object saved ....... aisdk_20180101_10.pkl
# MMSI 211202730 found valid .......
# 11 th object saved ....... aisdk_20180101_11.pkl
# MMSI 211265610 found valid .......
# 972 th object saved ....... aisdk_20180101_972.pkl
# MMSI 230352000 found valid .......
# 973 th object saved ....... aisdk_20180101_973.pkl
# MMSI 236610000 found valid .......
# 974 th object saved ....... aisdk_20180101_974.pkl
# MMSI 245014000 found valid .......
# 975 th object saved ....... aisdk_20180101_975.pkl
# MMSI 245147000 found valid .......
# 976 th object saved ....... aisdk_20180101_976.pkl
# MMSI 245909000 found valid .......
# 977 th object saved ....... aisdk_20180101_977.pkl
# MMSI 255805557 found valid .......
# 978 th object saved ....... aisdk_20180101_978.pkl
# MMSI 255805594 found valid .......
# 979 th object saved ....... aisdk_20180101_979.pkl
# MMSI 258915000 found valid .......
# 980 th object saved ....... aisdk_20180101_980.pkl
# MMSI 305184000 found valid .......
# 981 th object saved ....... aisdk_20180101_981.pkl
# MMSI 314182000 found valid .......
# 982 th object saved ....... aisdk_20180101_982.pkl
# MMSI 209467000 found valid .......
# 983 th object saved ....... aisdk_20180101_983.pkl
# MMSI 211187510 found valid .......
# 984 th object saved ....... aisdk_20180101_984.pkl
# MMSI 211265610 found valid .......
# 985 th object saved ....... aisdk_20180101_985.pkl
# MMSI 211570140 found valid .......
# 986 th object saved ....... aisdk_20180101_986.pkl
# MMSI 212423000 found valid .......
# 987 th object saved ....... aisdk_20180101_987.pkl
# MMSI 230352000 found valid .......
# 988 th object saved ....... aisdk_20180101_988.pkl
# MMSI 244621000 found valid .......
# 989 th object saved ....... aisdk_20180101_989.pkl
# MMSI 245241000 found valid .......
# 990 th object saved ....... aisdk_20180101_990.pkl
# MMSI 249359000 found valid .......
# 991 th object saved ....... aisdk_20180101_991.pkl
# MMSI 255805557 found valid .......
# 992 th object saved ....... aisdk_20180101_992.pkl
# MMSI 273358960 found valid .......
# 993 th object saved ....... aisdk_20180101_993.pkl
# MMSI 314182000 found valid .......
# 994 th object saved ....... aisdk_20180101_994.pkl
# MMSI 314415000 found valid .......
# 995 th object saved ....... aisdk_20180101_995.pkl
# MMSI 259255000 found valid .......
# 996 th object saved ....... aisdk_20180101_996.pkl
# MMSI 218085000 found valid .......
# 997 th object saved ....... aisdk_20180101_997.pkl
# MMSI 219592000 found valid .......
# 998 th object saved ....... aisdk_20180101_998.pkl
# MMSI 248006000 found valid .......
# 999 th object saved ....... aisdk_20180101_999.pkl
# MMSI 355444000 found valid .......
# 1000 th object saved ....... aisdk_20180101_1000.pkl
# MMSI 356928000 found valid .......
# 1001 th object saved ....... aisdk_20180101_1001.pkl
# MMSI 357562000 found valid .......
# 1002 th object saved ....... aisdk_20180101_1002.pkl
# MMSI 477115900 found valid .......
# 1003 th object saved ....... aisdk_20180101_1003.pkl
# MMSI 477967700 found valid .......
# 1004 th object saved ....... aisdk_20180101_1004.pkl
# MMSI 563002500 found valid .......
# 1005 th object saved ....... aisdk_20180101_1005.pkl
# MMSI 636015124 found valid .......
# 1006 th object saved ....... aisdk_20180101_1006.pkl

# %%
unpickled_df = pd.read_pickle("./dk_csv_20180101/aisdk_20180101_214.pkl")
unpickled_df
